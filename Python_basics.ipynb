# %% [markdown]
# <a href="https://colab.research.google.com/github/sonikasonikagowda01-stack/Python-basics/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet() :
    print("hello world")
greet()
# Out:
# hello world

# %%
print("Rino")
# Out:
# Rino

# %%
def greet(name) :
    print("hello", name)
greet("CSE")
greet("CSD")
greet("CIVIL")
greet("MECHANICAL")
# Out:
# hello CSE
# hello CSD
# hello CIVIL
# hello MECHANICAL
